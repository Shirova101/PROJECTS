# %% [markdown]
# Importing the Required Libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the Dataset

# %%
df=tf.keras.datasets.mnist
(X_train, y_train), (X_test, y_test) = df.load_data()

# %% [markdown]
# Data Preprocessing

# %%
x_train = tf.keras.utils.normalize(X_train, axis=1)
x_test = tf.keras.utils.normalize(X_test, axis=1)

# %% [markdown]
# Building the Model

# %%
model = tf.keras.models.Sequential()

model.add(tf.keras.layers.Flatten())

model.add(tf.keras.layers.Dense(256, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(64, activation=tf.nn.sigmoid))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

# %% [markdown]
# Compiling the Model

# %%
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# %% [markdown]
# Fitting the Model

# %%
model.fit(x=X_train, y=y_train, epochs=35)
# Out:
# Epoch 1/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0626 - accuracy: 0.9792
# Epoch 2/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0639 - accuracy: 0.9787
# Epoch 3/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0639 - accuracy: 0.9788
# Epoch 4/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0634 - accuracy: 0.9792
# Epoch 5/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0609 - accuracy: 0.9804
# Epoch 6/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0613 - accuracy: 0.9796
# Epoch 7/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0612 - accuracy: 0.9798
# Epoch 8/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0598 - accuracy: 0.9803
# Epoch 9/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0606 - accuracy: 0.9801
# Epoch 10/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0620 - accuracy: 0.9793
# Epoch 11/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0601 - accuracy: 0.9798
# Epoch 12/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0572 - accuracy: 0.9807
# Epoch 13/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0596 - accuracy: 0.9797
# Epoch 14/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0598 - accuracy: 0.9798
# Epoch 15/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0580 - accuracy: 0.9803
# Epoch 16/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0559 - accuracy: 0.9817
# Epoch 17/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0569 - accuracy: 0.9807
# Epoch 18/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0570 - accuracy: 0.9806
# Epoch 19/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0569 - accuracy: 0.9806
# Epoch 20/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0575 - accuracy: 0.9803
# Epoch 21/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0608 - accuracy: 0.9796
# Epoch 22/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0564 - accuracy: 0.9815
# Epoch 23/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0559 - accuracy: 0.9807
# Epoch 24/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0527 - accuracy: 0.9817
# Epoch 25/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0518 - accuracy: 0.9827
# Epoch 26/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0527 - accuracy: 0.9826
# Epoch 27/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0549 - accuracy: 0.9813
# Epoch 28/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0539 - accuracy: 0.9819
# Epoch 29/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0528 - accuracy: 0.9818
# Epoch 30/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0545 - accuracy: 0.9814
# Epoch 31/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0531 - accuracy: 0.9819
# Epoch 32/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0504 - accuracy: 0.9833
# Epoch 33/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0510 - accuracy: 0.9828
# Epoch 34/35
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0509 - accuracy: 0.9831
# Epoch 35/35
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0501 - accuracy: 0.9837

# %% [markdown]
# Evaluation

# %%
test_loss, test_acc = model.evaluate(x=x_test, y=y_test)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.1930 - accuracy: 0.9434
#
# Test accuracy: 0.9434000253677368
